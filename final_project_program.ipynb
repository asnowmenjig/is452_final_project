# %%
#VOLUME 1
# Dictionary content starts on line 7245
# A = lines 7245 to 33259 (26014 lines)
# B = lines 33260 to 56783 (23523 lines)
# C = lines 56784 to 98775 (41992 lines)
# D = lines 98776 to 124747 (25972 lines)
# E = lines 124748 to 141819 (17071 lines)
# F = lines 141820 to 165059 (23240 lines)
# G = lines 165060 to 179640 (14581 lines)
# H = lines 179641 to 194989 (15349 lines)
# IJ = lines 194990 to 215940 (20951 lines)
# K = lines 215941 to 218433 (2493 lines)

#VOLUME 2
# Dictionary content starts on line 85
# L = lines 85 to 15134             #page np-57
# M = lines 15137 to 35303          #page 58-162
# N = lines 35304 to 42147          #page 163-199
# O = lines 42148 to 52527          #page 200-255
# P = lines 52528 to 86702          #page 256-256
# Q = lines 86702 to 89231
# R = lines 89231 to 110052         #page 256-287
# S = lines 110053 to 163742        #page 288-np
# T = lines 163742 to 184958        #page np-np
# V/U = lines 184958 to 207127
# W = lines 207128 to 221750
# Y = lines 221750 to 222862
# Z = lines 222863 to 223136

#############################################

## CLEANING ##                                      #converts text to lowercase, cleans up punctuation and
                                                    # special characters, then outputs cleaned text
import string

def clean_line(line_str):
    cleanline = line_str.lower()
    for punc in string.punctuation:
         cleanline = cleanline.replace(punc, "")
    cleanline = cleanline.replace("rn", " ")
    cleanline = cleanline.replace('xc2xb', 'o')
    cleanline = cleanline.replace('xc2xba', 'o')
    cleanline = cleanline.replace('xc3x97', 'x')
    cleanline = cleanline.replace('xc3xa', 'a')
    cleanline = cleanline.replace('xc3xa1', 'a')
    cleanline = cleanline.replace('xc3xa2', 'a')
    cleanline = cleanline.replace('xc3xa4', 'a')
    cleanline = cleanline.replace('xc4x83', 'a')
    cleanline = cleanline.replace('xc3xa3', 'a')
    cleanline = cleanline.replace('xc3xa5', 'a')
    cleanline = cleanline.replace('xc4x81', 'a')
    cleanline = cleanline.replace('xc4x85', 'a')
    cleanline = cleanline.replace('xc4x87', 'c')
    cleanline = cleanline.replace('xc4x8d', 'c')
    cleanline = cleanline.replace('xc3xa7', 'c')
    cleanline = cleanline.replace('xc3xa8', 'e')
    cleanline = cleanline.replace('xc3xa9', 'e')
    cleanline = cleanline.replace('xc3xab', 'e')
    cleanline = cleanline.replace('xc4x93', 'e')
    cleanline = cleanline.replace('xc4x99', 'e')
    cleanline = cleanline.replace('xc3xa', 'e')
    cleanline = cleanline.replace('xc4x9f', 'g')
    cleanline = cleanline.replace('xc3xad', 'i')
    cleanline = cleanline.replace('xc3xac', 'i')
    cleanline = cleanline.replace('xc5x84', 'n')
    cleanline = cleanline.replace('xc3xb1', 'n')
    cleanline = cleanline.replace('xc5x88', 'n')
    cleanline = cleanline.replace('xc3xb3', 'o')
    cleanline = cleanline.replace('xc3xb6', 'o')
    cleanline = cleanline.replace('xc3xb', 'o')
    cleanline = cleanline.replace('xc3xb8', 'o')
    cleanline = cleanline.replace('xc3xb2', 'o')
    cleanline = cleanline.replace('xc5x99', 'r')
    cleanline = cleanline.replace('xc5xa1', 's')
    cleanline = cleanline.replace('xc5xbf', 's')
    cleanline = cleanline.replace('xc5x9b', 's')
    cleanline = cleanline.replace('xc5x9f', 's')
    cleanline = cleanline.replace('xc5xa3', 't')
    cleanline = cleanline.replace('xc3xbc', 'u')
    cleanline = cleanline.replace('xc3xba', 'u')
    cleanline = cleanline.replace('xc5xab', 'u')
    cleanline = cleanline.replace('xc5xba', 'z')
    cleanline = cleanline.replace('xc5xbc', 'z')
    cleanline = cleanline.replace('xc5xbe', 'z')
    cleanline = cleanline.replace('xc3x86', 'Æ')
    return cleanline

##########################################

## LIST OF WORDS ##

infile = open('johnson_v1_B.txt','rb')      #read alphabet section file           ######################
text = str(infile.read())
infile.close()

lines_list = text.split('\n')                                 #split text into list of lines
#print(lines_list)

for line in lines_list:                                       #clean list of lines
    clean = clean_line(line)
#    print(clean)
    clean_words = clean.split()                              #split cleaned lines into list of cleaned words
print(clean_words[0:100])

###########################################

## DICTIONARY COUNT ##                                        #adds words to dictionary and keeps count of frequency

word_counts = dict()                                          #create dictionary for word counts
for word in clean_words:
    if word not in word_counts:
        word_counts[word] = 1
    else:
        word_counts[word] += 1
# print(word_counts)

###########################################

## CSV COUNT ##                                     #writes dictionary (word_counts) contents to CSV file

import csv

outfile = open('wordcounts_v1_B.csv', 'w', newline = '', encoding='UTF-8')      ######################
csvout = csv.writer(outfile)
csvout.writerow(['word', 'count'])

for pair in word_counts.items():
    label = pair[0]
    count = pair[1]
    row = [label, count]
    csvout.writerow(row)
    
##########################################

## SHAKESPEARE COUNT ##
with open ('wordcounts_v1_B.csv', encoding='UTF-8') as csv_file:                ######################
    csv_reader = csv.reader(csv_file, delimiter=',')
    total_count = 0
    other_count = 0
    misc_list = []
    for row in csv_reader:
        if "shakes" in row[0]:
            total_count = total_count + int(row[1])
        elif "count" in row[1]:
            misc_list.append(row[1])
        else:
            other_count = other_count + int(row[1])
print("There are " + str(total_count) + " Shakespeare citations in this section")
# Out:
# ['bbr', 'xmlnsbr', 'xmlnspdivdiv', 'classpagediv', 'classpagenum', 'no', 'page', 'number', 'divp', 'classtextb', 'p', 'a', 'b', 'the', 'second', 'letter', 'of', 'the', 'english', 'alphabet', 'is', 'pro', 'nounced', 'as', 'in', 'most', 'other', 'european', 'languages', 'by', 'pressing', 'the', 'whole', 'length', 'of', 'the', 'lips', 'together', 'and', 'forcing', 'them', 'open', 'with', 'a', 'strong', 'breath', 'it', 'has', 'a', 'near', 'affinity', 'with', 'the', 'other', 'labial', 'letters', 'and', 'is', 'con', 'founded', 'by', 'the', 'germans', 'with', 'p', 'and', 'by', 'the', 'gascons', 'with', 'from', 'which', 'an', 'epigrammatist', 'remarks', 'that', 'libere', 'and', 'vivoare', 'are', 'in', 'gascony', 'the', 'same', 'the', 'spaniards', 'in', 'most', 'words', 'use', 'b', 'or', 'windifferently', 'baa', 'm', 's', 'see', 'the', 'verb', 'the']
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-23-817eb7d1e378> in <module>
#     139     other_count = 0
#     140     misc_list = []
# --> 141     for row in csv_reader:
#     142         if "shakes" in row[0]:
#     143             total_count = total_count + int(row[1])
#
# Error: line contains NULL byte
